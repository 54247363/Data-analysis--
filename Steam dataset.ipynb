# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

# %%
games = pd.read_csv("merged_data.csv")
games
# Out:
#                                     Title Original Price Discounted Price  \
# 0                         Baldur's Gate 3         $29.99           $29.99
# 1        Counter-Strike: Global Offensive         $14.99           $14.99
# 2                           Apex Legends™           Free             Free
# 3                         Forza Horizon 5         $34.78           $17.39
# 4                           Call of Duty®           Free             Free
# ...                                   ...            ...              ...
# 71695                           The Front           Free             Free
# 71696                        The Bornless           Free             Free
# 71697                     Winter Memories           Free             Free
# 71698  Call of Duty®: Modern Warfare® III         $69.99           $69.99
# 71699            Pixel Gun 3D: PC Edition           Free             Free
#
#           Release Date                                               Link  \
# ...

# %%
games.dtypes
# Out:
# Title                     object
# Original Price            object
# Discounted Price          object
# Release Date              object
# Link                      object
# Game Description          object
# Recent Reviews Summary    object
# All Reviews Summary       object
# Recent Reviews Number     object
# All Reviews Number        object
# Developer                 object
# Publisher                 object
# Supported Languages       object
# Popular Tags              object
# Game Features             object
# Minimum Requirements      object
# dtype: object

# %%
games['Title'] = games['Title'].astype('category')
games['Original Price'] = games['Original Price'].astype('category')
games['Discounted Price'] = games['Discounted Price'].astype('category')
games['Release Date'] = games['Release Date'].astype('category')
games['Link'] = games['Link'].astype('category')
games['Game Description'] = games['Game Description'].astype('category')
games['Recent Reviews Summary'] = games['Recent Reviews Summary'].astype('category')
games['All Reviews Summary'] = games['All Reviews Summary'].astype('category')
games['Recent Reviews Number'] = games['Recent Reviews Number'].astype('category')
games['All Reviews Number'] = games['All Reviews Number'].astype('category')
games['Developer'] = games['Developer'].astype('category')
games['Publisher'] = games['Publisher'].astype('category')
games['Supported Languages'] = games['Supported Languages'].astype('category')
games['Popular Tags'] = games['Popular Tags'].astype('category')
games['Game Features'] = games['Game Features'].astype('category')
games['Minimum Requirements'] = games['Minimum Requirements'].astype('category')

# %%
games.dtypes
# Out:
# Title                     category
# Original Price            category
# Discounted Price          category
# Release Date              category
# Link                      category
# Game Description          category
# Recent Reviews Summary    category
# All Reviews Summary       category
# Recent Reviews Number     category
# All Reviews Number        category
# Developer                 category
# Publisher                 category
# Supported Languages       category
# Popular Tags              category
# Game Features             category
# Minimum Requirements      category
# dtype: object

# %%
games.shape
# Out:
# (71700, 16)

# %%
games.isnull().sum()
# Out:
# Title                         1
# Original Price                0
# Discounted Price              0
# Release Date                131
# Link                          0
# Game Description            211
# Recent Reviews Summary    15220
# All Reviews Summary       66329
# Recent Reviews Number     15220
# All Reviews Number        66329
# Developer                   221
# Publisher                   517
# Supported Languages           0
# Popular Tags                  0
# Game Features                 0
# Minimum Requirements       1124
# dtype: int64

# %%
games.drop('Discounted Price', axis = 1, inplace = True)
games.drop('Original Price', axis = 1, inplace = True)
games.drop('Release Date', axis = 1, inplace = True)
games.drop('Link', axis = 1, inplace = True)
games.drop('Game Description', axis = 1, inplace = True)
games.drop('Recent Reviews Summary', axis = 1, inplace = True)
games.drop('All Reviews Summary', axis = 1, inplace = True)
games.drop('Recent Reviews Number', axis = 1, inplace = True)
games.drop('All Reviews Number', axis = 1, inplace = True)
games.drop('Game Features', axis = 1, inplace = True)
games.drop('Minimum Requirements', axis = 1, inplace = True)
games.drop('Supported Languages', axis = 1, inplace = True)
games.drop('Developer', axis = 1, inplace = True)
games.drop('Publisher', axis = 1, inplace = True)

# %%
games
# Out:
#                                     Title  \
# 0                         Baldur's Gate 3
# 1        Counter-Strike: Global Offensive
# 2                           Apex Legends™
# 3                         Forza Horizon 5
# 4                           Call of Duty®
# ...                                   ...
# 71695                           The Front
# 71696                        The Bornless
# 71697                     Winter Memories
# 71698  Call of Duty®: Modern Warfare® III
# 71699            Pixel Gun 3D: PC Edition
#
#                                             Popular Tags
# 0      ['RPG', 'Choices Matter', 'Character Customiza...
# 1      ['FPS', 'Shooter', 'Multiplayer', 'Competitive...
# 2      ['Free to Play', 'Multiplayer', 'Battle Royale...
# 3      ['Racing', 'Open World', 'Driving', 'Multiplay...
# 4      ['FPS', 'Multiplayer', 'Shooter', 'Action', 'S...
# ...                                                  ...
# ...

# %%
games = pd.get_dummies(games, columns=['Popular Tags'], drop_first=True)
games
# Out:
#                                     Title  \
# 0                         Baldur's Gate 3
# 1        Counter-Strike: Global Offensive
# 2                           Apex Legends™
# 3                         Forza Horizon 5
# 4                           Call of Duty®
# ...                                   ...
# 71695                           The Front
# 71696                        The Bornless
# 71697                     Winter Memories
# 71698  Call of Duty®: Modern Warfare® III
# 71699            Pixel Gun 3D: PC Edition
#
#        Popular Tags_["1990's", 'Casual', 'Interactive Fiction', 'Choose Your Own Adventure', 'Retro', 'Pixel Graphics', 'Dark Comedy', 'Old School', 'Lore-Rich', 'Exploration', '2D', 'Atmospheric', 'Dark', 'Dark Fantasy', 'Dark Humor', 'Fantasy', 'Gothic', 'Horror', 'Hunting', 'Mystery']  \
# 0                                                  False
# 1                                                  False
# ...

# %%
predictors_train, predictors_test, target_train, target_test = train_test_split(predictors_normalized, target, test_size=0.3, random_state=0)
print(predictors_train.shape, predictors_test.shape, target_train.shape, target_test.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Untitled-1.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X36sdW50aXRsZWQ%3D?line=0'>1</a> predictors_train, predictors_test, target_train, target_test = train_test_split(predictors_normalized, target, test_size=0.3, random_state=0)
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X36sdW50aXRsZWQ%3D?line=1'>2</a> print(predictors_train.shape, predictors_test.shape, target_train.shape, target_test.shape)
#
# NameError: name 'train_test_split' is not defined

# %%
model1 =  KNeighborsClassifier(n_neighbors=1)
model1.fit(predictors_train, target_train)

KNeighborsClassifier(n_neighbors=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Untitled-1.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X35sdW50aXRsZWQ%3D?line=0'>1</a> model1 =  KNeighborsClassifier(n_neighbors=1)
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X35sdW50aXRsZWQ%3D?line=1'>2</a> model1.fit(predictors_train, target_train)
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X35sdW50aXRsZWQ%3D?line=3'>4</a> KNeighborsClassifier(n_neighbors=1)
#
# NameError: name 'KNeighborsClassifier' is not defined

# %%
games['Developer'].describe()
# Out:
# count               71479
# unique              45353
# top       Choice of Games
# freq                  162
# Name: Developer, dtype: object

# %%
games['Developer'].value_counts()
# Out:
# Developer
# Choice of Games                            162
# Creobit                                    136
# Laush Dmitriy Sergeevich                   119
# Boogygames Studios                         106
# Sokpop Collective                          101
#                                           ...
# HunDong Studio                               1
# HunGames                                     1
# Hunex                                        1
# Hungaz Studios, Opus Technology Limited      1
# 📚瓜山书坊Guashan Bookshop                        1
# Name: count, Length: 45353, dtype: int64

# %%
games['Developer'].value_counts(normalize=True)
# Out:
# Developer
# Choice of Games                            0.002266
# Creobit                                    0.001903
# Laush Dmitriy Sergeevich                   0.001665
# Boogygames Studios                         0.001483
# Sokpop Collective                          0.001413
#                                              ...
# HunDong Studio                             0.000014
# HunGames                                   0.000014
# Hunex                                      0.000014
# Hungaz Studios, Opus Technology Limited    0.000014
# 📚瓜山书坊Guashan Bookshop                      0.000014
# Name: proportion, Length: 45353, dtype: float64

# %%
snsplot = sns.countplot(x='Developer', data=games)
snsplot.set_xticklabels(snsplot.get_xticklabels(), rotation=40, ha="right")
# Out:
# /var/folders/mz/zlmjw5d13vb1j4bw9q0h0zzm0000gn/T/ipykernel_28965/4055681008.py:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   snsplot.set_xticklabels(snsplot.get_xticklabels(), rotation=40, ha="right")
# [Text(0, 0, '!CyberApex (SkagoGames)'),
#  Text(1, 0, '"Nieko"'),
#  Text(2, 0, '"RevDay Studio"'),
#  Text(3, 0, '#12'),
#  Text(4, 0, '#LOL Entertainment'),
#  Text(5, 0, '#NVJOB'),
#  Text(6, 0, '#workshop'),
#  Text(7, 0, '$mitE'),
#  Text(8, 0, "'Kill On Sight' Game development"),
#  Text(9, 0, "'What Day is it?' Games"),
#  Text(10, 0, '((no-end-parens Studio'),
#  Text(11, 0, '(Just)Jordan'),
#  Text(12, 0, '(STCG) Smoker The Car Game'),
#  Text(13, 0, '(주)펀웨이브'),
#  Text(14, 0, '+7 Software'),
#  Text(15, 0, '+Mpact Games, LLC.'),
#  Text(16, 0, '+Umbrella'),
#  Text(17, 0, '-Yodasaurus- Games'),
#  Text(18, 0, '-乌鸦男-'),
#  Text(19, 0, '.Cat'),
#  Text(20, 0, '.M.Y.W.'),
#  Text(21, 0, '.ToNg'),
#  Text(22, 0, '.ez Games'),
# ...
